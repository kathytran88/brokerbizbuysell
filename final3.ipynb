# %%
import pandas as pd 
import numpy as np 

df = pd.read_excel('official3.xlsx')
del df['Unnamed: 0']
df.head()
# Out:
#             phone                                            company  \
# 0  (256) 309-7556               Access Commercial & Business Brokers
# 1  (205) 294-9148                           Alabama Business Brokers
# 2  (251) 233-9942                               TNT Business Brokers
# 3  (251) 278-8171  Sunbelt Business Brokers and Business Brokers ...
# 4  (208) 870-1717                                  Business Resource
#
#                  location                                               link  \
# 0         Decatur,Alabama  https://www.bizbuysell.com/business-broker/sam...
# 1         Clanton,Alabama  https://www.bizbuysell.com/business-broker/bra...
# 2    Orange Beach,Alabama  https://www.bizbuysell.com/business-broker/wyn...
# 3          Daphne,Alabama  https://www.bizbuysell.com/business-broker/dav...
# 4  Mountain Brook,Alabama  https://www.bizbuysell.com/business-broker/wil...
#
#              name    state            city first name last name
# ...

# %%
df.shape
# Out:
# (5057, 9)

# %%
df = df[['company', 'first name', 'last name', 'name', 'phone', 'location', 'city', 'state', 'link']]
df.head()
# Out:
#                                              company first name last name  \
# 0               Access Commercial & Business Brokers        Sam     Mozeb
# 1                           Alabama Business Brokers       Brad      Owen
# 2                               TNT Business Brokers     Wyndee   Townley
# 3  Sunbelt Business Brokers and Business Brokers ...      David      Chew
# 4                                  Business Resource     Wilson    Archer
#
#              name           phone                location            city  \
# 0       Sam Mozeb  (256) 309-7556         Decatur,Alabama         Decatur
# 1       Brad Owen  (205) 294-9148         Clanton,Alabama         Clanton
# 2  Wyndee Townley  (251) 233-9942    Orange Beach,Alabama    Orange Beach
# 3      David Chew  (251) 278-8171          Daphne,Alabama          Daphne
# 4   Wilson Archer  (208) 870-1717  Mountain Brook,Alabama  Mountain Brook
#
#      state                                               link
# ...

# %%
df = df.rename(columns = {'company': 'Company' , 'first name': 'First Name', 'last name': 'Last Name', 'name': 'Full Name', 'phone': 'Corporate Phone', 'location': 'Location', 'city': 'City', 'state': 'State', 'link': 'Profile Link'})
df.head()
# Out:
#                                              Company First Name Last Name  \
# 0               Access Commercial & Business Brokers        Sam     Mozeb
# 1                           Alabama Business Brokers       Brad      Owen
# 2                               TNT Business Brokers     Wyndee   Townley
# 3  Sunbelt Business Brokers and Business Brokers ...      David      Chew
# 4                                  Business Resource     Wilson    Archer
#
#         Full Name Corporate Phone                Location            City  \
# 0       Sam Mozeb  (256) 309-7556         Decatur,Alabama         Decatur
# 1       Brad Owen  (205) 294-9148         Clanton,Alabama         Clanton
# 2  Wyndee Townley  (251) 233-9942    Orange Beach,Alabama    Orange Beach
# 3      David Chew  (251) 278-8171          Daphne,Alabama          Daphne
# 4   Wilson Archer  (208) 870-1717  Mountain Brook,Alabama  Mountain Brook
#
#      State                                       Profile Link
# ...

# %%
df.shape
# Out:
# (5057, 9)

# %%
df.to_excel('official4.xlsx')
