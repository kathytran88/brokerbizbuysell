# %%
import pandas as pd 
import numpy as np 

df = pd.read_excel('official2.xlsx')
del df['Unnamed: 0']
df.head()
# Out:
#             phone                             company  \
# 0  (301) 458-0884              Burley Consulting, LLC
# 1  (732) 449-2000  Sitar Realty Company TCN WORLDWIDE
# 2  (732) 915-0926               Resources Real Estate
# 3  (907) 371-3070                   Walden Home Group
# 4  (907) 841-3214               Powers Land Brokerage
#
#                           location  \
# 0           Gaithersburg, Maryland
# 1             Sea Girt, New Jersey
# 2           Shrewsbury, New Jersey
# 3  Fairbanks North Star County, AK
# 4             Anchorage County, AK
#
#                                                 link            name  \
# 0  https://www.bizbuysell.com/business-broker/joh...     John Burley
# 1  https://www.bizbuysell.com/business-broker/hel...  Helena Loelius
# 2  https://www.bizbuysell.com/business-broker/sah...  Sahar Karykous
# 3  https://www.bizbuysell.com/business-broker/gar...  Gary Gallemore
# 4  https://www.bizbuysell.com/business-broker/ker...    Kerry Powers
#
# ...

# %%
df.shape
# Out:
# (5058, 9)

# %%
# Strip spaces of the state column 
df['state'] = df['state'].str.strip()

# %%
state_abbreviations = {
    'AL': 'Alabama', 'AK': 'Alaska', 'AZ': 'Arizona', 'AR': 'Arkansas', 'CA': 'California', 'CO': 'Colorado',
    'CT': 'Connecticut', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia', 'HI': 'Hawaii', 'ID': 'Idaho',
    'IL': 'Illinois', 'IN': 'Indiana', 'IA': 'Iowa', 'KS': 'Kansas', 'KY': 'Kentucky', 'LA': 'Louisiana',
    'ME': 'Maine', 'MD': 'Maryland', 'MA': 'Massachusetts', 'MI': 'Michigan', 'MN': 'Minnesota', 'MS': 'Mississippi',
    'MO': 'Missouri', 'MT': 'Montana', 'NE': 'Nebraska', 'NV': 'Nevada', 'NH': 'New Hampshire', 'NJ': 'New Jersey',
    'NM': 'New Mexico', 'NY': 'New York', 'NC': 'North Carolina', 'ND': 'North Dakota', 'OH': 'Ohio', 'OK': 'Oklahoma',
    'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island', 'SC': 'South Carolina', 'SD': 'South Dakota',
    'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VT': 'Vermont', 'VA': 'Virginia', 'WA': 'Washington',
    'WV': 'West Virginia', 'WI': 'Wisconsin', 'WY': 'Wyoming'
}

# %%
for num in range(len(df['state'])):
    if df['state'][num] in state_abbreviations:
        the_state = df['state'][num]
        print(df['state'][num], 'to', state_abbreviations[the_state])
        df.loc[num, 'state'] = state_abbreviations[the_state]
# Out:
# AK to Alaska
# AK to Alaska
# AK to Alaska
# AL to Alabama
# AL to Alabama
# AL to Alabama
# AL to Alabama
# AL to Alabama
# AL to Alabama
# AL to Alabama
# AL to Alabama
# AL to Alabama
# AL to Alabama
# AL to Alabama
# AR to Arkansas
# AR to Arkansas
# AR to Arkansas
# AR to Arkansas
# AR to Arkansas
# AR to Arkansas
# AR to Arkansas
# AZ to Arizona
# AZ to Arizona
# AZ to Arizona
# AZ to Arizona
# AZ to Arizona
# AZ to Arizona
# AZ to Arizona
# AZ to Arizona
# AZ to Arizona
# AZ to Arizona
# AZ to Arizona
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# CA to California
# ...

# %%
df.head(10)
# Out:
#                     phone                                         company  \
# 0          (301) 458-0884                          Burley Consulting, LLC
# 1          (732) 449-2000              Sitar Realty Company TCN WORLDWIDE
# 2          (732) 915-0926                           Resources Real Estate
# 3          (907) 371-3070                               Walden Home Group
# 4          (907) 841-3214                           Powers Land Brokerage
# 5          (907) 313-7447          Transworld Business Advisors of Alaska
# 6          (251) 237-1030  Transworld Business Advisors of the Gulf Coast
# 7          (251) 459-2712  Transworld Business Advisors of the Gulf Coast
# 8          (205) 492-8598                              Optics Capital LLC
# 9  (251) 237-1030ext. 701  Transworld Business Advisors of the Gulf Coast
#
#                           location  \
# 0           Gaithersburg, Maryland
# 1             Sea Girt, New Jersey
# 2           Shrewsbury, New Jersey
# ...

# %%
df = df.sort_values(by='state')
df.head()
# Out:
#                phone                                            company  \
# 1009  (256) 309-7556               Access Commercial & Business Brokers
# 995   (205) 294-9148                           Alabama Business Brokers
# 996   (251) 233-9942                               TNT Business Brokers
# 997   (251) 278-8171  Sunbelt Business Brokers and Business Brokers ...
# 998   (208) 870-1717                                  Business Resource
#
#                     location  \
# 1009         Decatur,Alabama
# 995          Clanton,Alabama
# 996     Orange Beach,Alabama
# 997           Daphne,Alabama
# 998   Mountain Brook,Alabama
#
#                                                    link            name  \
# 1009  https://www.bizbuysell.com/business-broker/sam...       Sam Mozeb
# 995   https://www.bizbuysell.com/business-broker/bra...       Brad Owen
# 996   https://www.bizbuysell.com/business-broker/wyn...  Wyndee Townley
# ...

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#             phone                                            company  \
# 0  (256) 309-7556               Access Commercial & Business Brokers
# 1  (205) 294-9148                           Alabama Business Brokers
# 2  (251) 233-9942                               TNT Business Brokers
# 3  (251) 278-8171  Sunbelt Business Brokers and Business Brokers ...
# 4  (208) 870-1717                                  Business Resource
#
#                  location                                               link  \
# 0         Decatur,Alabama  https://www.bizbuysell.com/business-broker/sam...
# 1         Clanton,Alabama  https://www.bizbuysell.com/business-broker/bra...
# 2    Orange Beach,Alabama  https://www.bizbuysell.com/business-broker/wyn...
# 3          Daphne,Alabama  https://www.bizbuysell.com/business-broker/dav...
# 4  Mountain Brook,Alabama  https://www.bizbuysell.com/business-broker/wil...
#
#              name    state            city first name last name
# ...

# %%
df.to_excel('official3.xlsx')
