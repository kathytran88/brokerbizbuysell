# %%
import pandas as pd 
import numpy as np 

df = pd.read_excel('official2.xlsx')
del df['Unnamed: 0']
df.head()
# Out:
#                      name           phone  \
# 0  A. Bert Risdon, B.C.I.  (407) 797-6300
# 1   A. John Richwine CCIM  (904) 996-0699
# 2     AJ (Alpesh Jayswal)  (630) 544-0611
# 3              AJ Ajendla  (424) 253-6352
# 4               AJ Jafari  (703) 402-9558
#
#                                        company                    state  \
# 0              Florida Business Exchange, Inc.    Daytona Beach,Florida
# 1                         MarketPoint Advisors         Duval County, FL
# 2  Transworld Business Advisors of St. Charles     St. Charles,Illinois
# 3                          Link Silicon Valley  Contra Costa County, CA
# 4                             Nova Concept INC        Sterling,Virginia
#
#                                                 link
# 0  https://www.bizbuysell.com/business-broker/a-b...
# 1  https://www.bizbuysell.com/business-broker/a-j...
# 2  https://www.bizbuysell.com/business-broker/aj-...
# 3  https://www.bizbuysell.com/business-broker/aj-...
# ...

# %%
print(len(df))
# Out:
# 5134

# %%
df = df.drop_duplicates(subset=['name', 'phone'], keep='first')
df.shape
# Out:
# (5093, 5)

# %%
phone_dup = df['name'].duplicated()
phone_dup_df = df[phone_dup]
display(phone_dup_df)
# Out:
#                                                name              phone  \
# 49          Adam Edwards, NFL Alumni, CFE, CTA, CMR  Show Phone Number
# 62                                       Adam Smith  Show Phone Number
# 65                                      Adam Weaver     (615) 450-0410
# 70                                   Adrianna Smith     (424) 272-1773
# 82                        Al Fialkovich, CBI, CM&AA     (817) 677-9988
# ...                                             ...                ...
# 4955  Vasilis Georgiou, CM&AA, M&AMI, CBI, CBB, MBA  Show Phone Number
# 5033                                     Wes Martin     (206) 276-4894
# 5063                                  William White     (330) 650-9000
# 5085                                      Young Lee     (404) 509-6874
# 5091                                  Yvette Criner     (346) 370-7980
#
#                                       company                   state  \
# ...
